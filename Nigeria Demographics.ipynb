# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('NIGERIA_DEMOGRAPHICS_DATA.CSV')

# %%
data
# Out:
#                Timestamp Are you a Nigerian?             Gender Age Group  \
# 0    10/13/2019 17:45:01                 NaN             Female   18 – 25
# 1    10/13/2019 18:13:59                 NaN             Female   18 – 25
# 2    10/13/2019 20:11:39                 NaN               Male   36 – 45
# 3    10/13/2019 20:17:57                 NaN             Female   26 – 35
# 4     10/14/2019 6:24:13                 NaN               Male   26 – 35
# 5     10/14/2019 9:09:01                 NaN               Male   26 – 35
# 6     10/14/2019 9:14:46                 NaN               Male   26 – 35
# 7     10/14/2019 9:28:46                 NaN             Female   18 – 25
# 8    10/14/2019 14:48:58                 NaN               Male   18 – 25
# 9    10/14/2019 17:13:59                 NaN               Male   18 – 25
# 10   10/14/2019 17:18:08                 NaN             Female   26 – 35
# 11   10/14/2019 20:40:20                 NaN               Male   18 – 25
# ...

# %%
data.head()
# Out:
#              Timestamp Are you a Nigerian?  Gender Age Group Are you married?  \
# 0  10/13/2019 17:45:01                 NaN  Female   18 – 25               No
# 1  10/13/2019 18:13:59                 NaN  Female   18 – 25               No
# 2  10/13/2019 20:11:39                 NaN    Male   36 – 45              Yes
# 3  10/13/2019 20:17:57                 NaN  Female   26 – 35               No
# 4   10/14/2019 6:24:13                 NaN    Male   26 – 35               No
#
#   Do you have kids? Where do you live?  \
# 0                No              Lagos
# 1                No              Lagos
# 2               Yes              Lagos
# 3                No              Lagos
# 4                No              Lagos
#
#   What part of your state do you live in?          Occupation  \
# 0                                   Rural                 NaN
# 1                                   Rural              No Job
# 2                                    City  Financial Services
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 22 columns):
# Timestamp                                                                             303 non-null object
# Are you a Nigerian?                                                                   288 non-null object
# Gender                                                                                303 non-null object
# Age Group                                                                             303 non-null object
# Are you married?                                                                      303 non-null object
# Do you have kids?                                                                     303 non-null object
# Where do you live?                                                                    303 non-null object
# What part of your state do you live in?                                               303 non-null object
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Are you a Nigerian?', 'Gender', 'Age Group',
#        'Are you married?', 'Do you have kids?', 'Where do you live?',
#        'What part of your state do you live in?', 'Occupation',
#        'Are you Happy with your job?',
#        'Is this your primary source of income?',
#        'What is your steady/constant income range in a month?',
#        'Do you think it is enough for you and your family?',
#        'What are your other sources of income? ', 'Do you pay your tax?',
#        'What is your largest form of expense',
#        'If there was one thing you really wanted to own, what would that be?',
#        'How much do you think you earn from all other sources of income in a month',
#        'On an average, how much do you think you spend in a month?',
#        'Do you think Nigeria can get better?',
#        'In a short sentence, describe your government',
#        'Please fill your email if you want to be notified once this research is completed.'],
# ...

# %%
data['Are you married?'].value_counts()
# Out:
# No     269
# Yes     34
# Name: Are you married?, dtype: int64

# %%
data['Occupation'].value_counts()
# Out:
# Software Engineering /Computer Design    50
# Student                                  48
# Engineering                              31
# Entrepreneur                             28
# Financial Services                       27
# No Job                                   25
# Student and Working                      23
# Others                                   18
# Consultant                               16
# Business                                 16
# Health                                   10
# I don’t know                              9
# Farmer                                    1
# Name: Occupation, dtype: int64

# %%
data['Occupation'].nunique()
# Out:
# 13

# %%
data['If there was one thing you really wanted to own, what would that be?'].value_counts()
# Out:
# A Company    130
# A House       80
# Money         55
# Others        26
# A Car         11
# A Boat         1
# Name: If there was one thing you really wanted to own, what would that be?, dtype: int64

# %%
data['Do you think Nigeria can get better?'].value_counts()
# Out:
# Yes    224
# No      79
# Name: Do you think Nigeria can get better?, dtype: int64

# %%
data['Do you pay your tax?'].value_counts()
# Out:
# Yes    176
# No     127
# Name: Do you pay your tax?, dtype: int64

# %%
data['What is your largest form of expense'].value_counts()
# Out:
# Feeding                 102
# Transportation           82
# Rent                     63
# School Fees              23
# Airtime and Data         20
# Clothing and Jewelry      9
# Tax                       2
# Medical Bills             1
# Bribery                   1
# Name: What is your largest form of expense, dtype: int64

# %%
data['Is this your primary source of income?'].value_counts()
# Out:
# Yes    238
# No      65
# Name: Is this your primary source of income?, dtype: int64

# %%
data[ 'What are your other sources of income? '].value_counts()
# Out:
# None                                                     102
# Free Lancing                                              88
# Buying and Selling                                        34
# Formal Job                                                16
# Free Lancing, Buying and Selling                          14
# Contractor                                                12
# Betting (Bet Naija)                                       10
# Free Lancing, Betting (Bet Naija)                          7
# Free Lancing, Contractor                                   6
# Free Lancing, Formal Job                                   3
# Betting (Bet Naija), Buying and Selling                    3
# Free Lancing, Formal Job, Buying and Selling               2
# Free Lancing, Buying and Selling, Contractor               1
# Buying and Selling, Contractor                             1
# Free Lancing, Betting (Bet Naija), Buying and Selling      1
# ...

# %%
data['Age Group'].nunique()
# Out:
# 5

# %%
data['Age Group'].value_counts()
# Out:
# 18 – 25    181
# 26 – 35    104
# 36 – 45     13
# 46 – 55      4
# 56 – 65      1
# Name: Age Group, dtype: int64

# %%
plt.hist(data['Age Group'].value_counts())
# Out:
# (array([3., 0., 0., 0., 0., 1., 0., 0., 0., 1.]),
#  array([  1.,  19.,  37.,  55.,  73.,  91., 109., 127., 145., 163., 181.]),
#  <a list of 10 Patch objects>)

# %%
data['Is this your primary source of income?'].value_counts()
# Out:
# Yes    238
# No      65
# Name: Is this your primary source of income?, dtype: int64

# %%
data['What is your steady/constant income range in a month?'].value_counts()
# Out:
# 21,000 – 50,000      82
# 110,000 – 200,000    37
# 81,000 – 100,000     35
# 51,000 – 80,000      33
# 11,000 – 20,000      29
# Below 5000           29
# 201,000 – 300,000    23
# 5000 – 10,000        18
# 301,000 – 500,000     9
# 500,000 – above       8
# Name: What is your steady/constant income range in a month?, dtype: int64

# %%
data.rename(columns = {'Please fill your email if you want to be notified once this research is completed.': 'emails'}, inplace = True)

# %%
data.corr()
# Out:
#                                                     How much do you think you earn from all other sources of income in a month  \
# How much do you think you earn from all other s...                                           1.000000
# On an average, how much do you think you spend ...                                           0.705931
#
#                                                     On an average, how much do you think you spend in a month?
# How much do you think you earn from all other s...                                           0.705931
# On an average, how much do you think you spend ...                                           1.000000

# %%
data.plot.scatter(x='How much do you think you earn from all other sources of income in a month', y = 'On an average, how much do you think you spend in a month?' )

# %%
a = data.groupby(['Age Group', 'Occupation'])
a.head()
# Out:
#                Timestamp Are you a Nigerian?  Gender Age Group  \
# 0    10/13/2019 17:45:01                 NaN  Female   18 – 25
# 1    10/13/2019 18:13:59                 NaN  Female   18 – 25
# 2    10/13/2019 20:11:39                 NaN    Male   36 – 45
# 3    10/13/2019 20:17:57                 NaN  Female   26 – 35
# 4     10/14/2019 6:24:13                 NaN    Male   26 – 35
# 5     10/14/2019 9:09:01                 NaN    Male   26 – 35
# 6     10/14/2019 9:14:46                 NaN    Male   26 – 35
# 7     10/14/2019 9:28:46                 NaN  Female   18 – 25
# 8    10/14/2019 14:48:58                 NaN    Male   18 – 25
# 9    10/14/2019 17:13:59                 NaN    Male   18 – 25
# 10   10/14/2019 17:18:08                 NaN  Female   26 – 35
# 11   10/14/2019 20:40:20                 NaN    Male   18 – 25
# 12   10/15/2019 10:51:56                 NaN  Female   18 – 25
# 13   10/15/2019 11:06:42                 NaN    Male   18 – 25
# ...

# %%
p = data.filter(['Age Group','Occupation', 'What is your steady/constant income range in a month?'])

# %%
p.head()
# Out:
#   Age Group          Occupation  \
# 0   18 – 25                 NaN
# 1   18 – 25              No Job
# 2   36 – 45  Financial Services
# 3   26 – 35            Business
# 4   26 – 35         Engineering
#
#   What is your steady/constant income range in a month?
# 0                                         Below 5000
# 1                                    11,000 – 20,000
# 2                                  110,000 – 200,000
# 3                                  201,000 – 300,000
# 4                                  110,000 – 200,000

# %%
student_cash= p[(p['Occupation']== 'Student') & (p['What is your steady/constant income range in a month?'] == 'Below 5000')]
len(student_cash)
# Out:
# 7

# %%
stu_cash = p[(p['Occupation']== 'Student') & (p['What is your steady/constant income range in a month?'] <= '51,000 - 80,000' )]
(stu_cash)
# Out:
#     Age Group Occupation What is your steady/constant income range in a month?
# 7     18 – 25    Student                                    11,000 – 20,000
# 13    18 – 25    Student                                    21,000 – 50,000
# 24    18 – 25    Student                                    11,000 – 20,000
# 25    18 – 25    Student                                    21,000 – 50,000
# 26    18 – 25    Student                                    21,000 – 50,000
# 27    18 – 25    Student                                    11,000 – 20,000
# 29    18 – 25    Student                                    21,000 – 50,000
# 32    18 – 25    Student                                    21,000 – 50,000
# 33    18 – 25    Student                                      5000 – 10,000
# 34    26 – 35    Student                                    21,000 – 50,000
# 92    18 – 25    Student                                      5000 – 10,000
# ...

# %% [markdown]
# from the cells above, we see that most students in the dataset earn a monthly income of less than 51,000 while only 7 of them earn below 5,000

# %%
#most finance guys are big spenders with income ranging btw 110k and above while just 3 make btw 21k - 50k
finance_guy =  p[(p['Occupation']== 'Financial Services') & (p['What is your steady/constant income range in a month?'] >= '110,000 - 200,000')]
(finance_guy)
# Out:
#     Age Group          Occupation  \
# 2     36 – 45  Financial Services
# 14    26 – 35  Financial Services
# 19    26 – 35  Financial Services
# 20    18 – 25  Financial Services
# 21    18 – 25  Financial Services
# 59    26 – 35  Financial Services
# 60    26 – 35  Financial Services
# 61    36 – 45  Financial Services
# 75    26 – 35  Financial Services
# 77    18 – 25  Financial Services
# 87    18 – 25  Financial Services
# 101   26 – 35  Financial Services
# 105   26 – 35  Financial Services
# 122   26 – 35  Financial Services
# 140   26 – 35  Financial Services
# 168   18 – 25  Financial Services
# 197   18 – 25  Financial Services
# 198   26 – 35  Financial Services
# 216   26 – 35  Financial Services
# 222   26 – 35  Financial Services
# 231   18 – 25  Financial Services
# 234   18 – 25  Financial Services
# 245   26 – 35  Financial Services
# 250   18 – 25  Financial Services
# 253   26 – 35  Financial Services
# 264   18 – 25  Financial Services
# ...

# %%
import seaborn as sns
import matplotlib as mpl

# %%
mpl.pyplot.figure(figsize = (18,6))
sns.countplot('What is your steady/constant income range in a month?', data = finance_guy)

# %%
sns.countplot?

# %%
tech_guys =  p[(p['Occupation']== 'Software Engineering /Computer Design') & (p['What is your steady/constant income range in a month?'] >= '201,000 - 300,000')]
(tech_guys)
# Out:
#     Age Group                             Occupation  \
# 6     26 – 35  Software Engineering /Computer Design
# 46    18 – 25  Software Engineering /Computer Design
# 54    26 – 35  Software Engineering /Computer Design
# 56    26 – 35  Software Engineering /Computer Design
# 66    18 – 25  Software Engineering /Computer Design
# 67    26 – 35  Software Engineering /Computer Design
# 68    26 – 35  Software Engineering /Computer Design
# 79    18 – 25  Software Engineering /Computer Design
# 82    18 – 25  Software Engineering /Computer Design
# 85    26 – 35  Software Engineering /Computer Design
# 88    26 – 35  Software Engineering /Computer Design
# 89    18 – 25  Software Engineering /Computer Design
# 91    18 – 25  Software Engineering /Computer Design
# 96    26 – 35  Software Engineering /Computer Design
# 103   26 – 35  Software Engineering /Computer Design
# 110   26 – 35  Software Engineering /Computer Design
# 111   18 – 25  Software Engineering /Computer Design
# ...

# %%
mpl.pyplot.figure(figsize = (18,6))
sns.countplot('What is your steady/constant income range in a month?', data = tech_guys )

# %%
dev = p[(p['Occupation'] == 'Software Engineering /Computer Design') & (p['What is your steady/constant income range in a month?'] <='110,000 – 200,000') ]
dev
# Out:
#     Age Group                             Occupation  \
# 23    18 – 25  Software Engineering /Computer Design
# 118   26 – 35  Software Engineering /Computer Design
# 123   18 – 25  Software Engineering /Computer Design
# 136   18 – 25  Software Engineering /Computer Design
# 141   26 – 35  Software Engineering /Computer Design
# 187   18 – 25  Software Engineering /Computer Design
# 208   18 – 25  Software Engineering /Computer Design
# 242   18 – 25  Software Engineering /Computer Design
#
#     What is your steady/constant income range in a month?
# 23                                   110,000 – 200,000
# 118                                  110,000 – 200,000
# 123                                  110,000 – 200,000
# 136                                  110,000 – 200,000
# 141                                  110,000 – 200,000
# 187                                    11,000 – 20,000
# 208                                  110,000 – 200,000
# ...

# %%
mpl.pyplot.figure(figsize = (18,6))
sns.countplot('What is your steady/constant income range in a month?', data = dev)

# %%
health_guys = p[(p['Occupation'] == 'Health') & (p['What is your steady/constant income range in a month?'] =='110,000 – 200,000') ]
(health_guys)
# Out:
#     Age Group Occupation What is your steady/constant income range in a month?
# 42    18 – 25     Health                                  110,000 – 200,000
# 232   18 – 25     Health                                  110,000 – 200,000

# %%
health__guys =  p[(p['Occupation'] == 'Health') & (p['What is your steady/constant income range in a month?'] >'110,000 – 200,000')]
(health__guys)
# Out:
#     Age Group Occupation What is your steady/constant income range in a month?
# 30    26 – 35     Health                                    51,000 – 80,000
# 63    26 – 35     Health                                   81,000 – 100,000
# 86    36 – 45     Health                                    51,000 – 80,000
# 120   18 – 25     Health                                    51,000 – 80,000
# 148   18 – 25     Health                                      5000 – 10,000
# 155   18 – 25     Health                                    21,000 – 50,000
# 214   18 – 25     Health                                    51,000 – 80,000
# 215   18 – 25     Health                                   81,000 – 100,000

# %%
Health__ = p[(p['Occupation']== 'Health') & (p['What is your steady/constant income range in a month?'] > '201,000 - 300,000')]
(Health__)
# Out:
#     Age Group Occupation What is your steady/constant income range in a month?
# 30    26 – 35     Health                                    51,000 – 80,000
# 63    26 – 35     Health                                   81,000 – 100,000
# 86    36 – 45     Health                                    51,000 – 80,000
# 120   18 – 25     Health                                    51,000 – 80,000
# 148   18 – 25     Health                                      5000 – 10,000
# 155   18 – 25     Health                                    21,000 – 50,000
# 214   18 – 25     Health                                    51,000 – 80,000
# 215   18 – 25     Health                                   81,000 – 100,000

# %% [markdown]
# from the cells above, it seems that only 2 respondents from the dataset earna between the range 110,000 - 200,000 while the rest of the respondent earns lower than that.

# %%
tab =  data.filter(['Occupation','What is your largest form of expense', 'If there was one thing you really wanted to own, what would that be?', 'On an average, how much do you think you spend in a month?'  ])
tab.head()
# Out:
#            Occupation What is your largest form of expense  \
# 0                 NaN                              Feeding
# 1              No Job                       Transportation
# 2  Financial Services                          School Fees
# 3            Business                       Transportation
# 4         Engineering                       Transportation
#
#   If there was one thing you really wanted to own, what would that be?  \
# 0                                          A Company
# 1                                            A House
# 2                                          A Company
# 3                                              Money
# 4                                          A Company
#
#    On an average, how much do you think you spend in a month?
# 0                                              25000
# 1                                              20000
# 2                                             140000
# ...

# %%
dff = tab.groupby(['Occupation', 'What is your largest form of expense'])

# %%
# We notice that entrepreneurs choose mostly between owning a company, house or money!
entre = tab[(tab['Occupation']== 'Entrepreneur') & (tab['If there was one thing you really wanted to own, what would that be?' ])]
(entre)
# Out:
#        Occupation What is your largest form of expense  \
# 8    Entrepreneur                              Feeding
# 9    Entrepreneur                              Feeding
# 17   Entrepreneur                              Feeding
# 22   Entrepreneur                                 Rent
# 35   Entrepreneur                 Clothing and Jewelry
# 36   Entrepreneur                                 Rent
# 45   Entrepreneur                                 Rent
# 53   Entrepreneur                       Transportation
# 58   Entrepreneur                       Transportation
# 62   Entrepreneur                                 Rent
# 65   Entrepreneur                              Feeding
# 72   Entrepreneur                          School Fees
# 74   Entrepreneur                              Feeding
# 76   Entrepreneur                       Transportation
# 102  Entrepreneur                              Feeding
# 173  Entrepreneur                       Transportation
# ...

# %%
mpl.pyplot.figure(figsize = (18,6))
sns.countplot('If there was one thing you really wanted to own, what would that be?', data= entre)

# %%
business = tab[(tab['Occupation']== 'Business') & (tab['If there was one thing you really wanted to own, what would that be?' ])]
(business)
# Out:
#     Occupation What is your largest form of expense  \
# 3     Business                       Transportation
# 43    Business                                 Rent
# 81    Business                              Feeding
# 97    Business                              Feeding
# 116   Business                       Transportation
# 135   Business                 Clothing and Jewelry
# 137   Business                              Feeding
# 179   Business                          School Fees
# 180   Business                              Feeding
# 200   Business                       Transportation
# 217   Business                                 Rent
# 224   Business                       Transportation
# 246   Business                                 Rent
# 258   Business                              Feeding
# 259   Business                          School Fees
# 269   Business                              Feeding
#
# ...

# %%
mpl.pyplot.figure(figsize = (18,6))
sns.countplot('If there was one thing you really wanted to own, what would that be?', data = business)

# %% [markdown]
# from the cell above, majority of the business owners would really want to a company whie other are divided between owning a house, money and others unspecified.

# %%
dam = data.filter(['Occupation' , 'Do you think it is enough for you and your family?'] )
dam.head()
# Out:
#            Occupation Do you think it is enough for you and your family?
# 0                 NaN                                                 No
# 1              No Job                                                 No
# 2  Financial Services                                                 No
# 3            Business                                                 No
# 4         Engineering                                                Yes

# %%
second_income = dam[(dam['Occupation']== 'Consultant') & (dam['Do you think it is enough for you and your family?'])]
second_income
# Out:
#      Occupation Do you think it is enough for you and your family?
# 5    Consultant                                                 No
# 16   Consultant                                                 No
# 38   Consultant                                                 No
# 40   Consultant                                                 No
# 121  Consultant                                                 No
# 150  Consultant                                                Yes
# 158  Consultant                                                 No
# 163  Consultant                                                 No
# 170  Consultant                                                 No
# 186  Consultant                                                 No
# 195  Consultant                                                 No
# 201  Consultant                                                 No
# 252  Consultant                                                 No
# ...

# %%
mpl.pyplot.figure(figsize = (10,6))
sns.countplot('Do you think it is enough for you and your family?', data = second_income)

# %% [markdown]
# from the above cell, over 95% of consultants in the dataset thinks that their income isnt enough for their family

# %%
second_ = dam[(dam['Occupation']== 'Engineering') & (dam['Do you think it is enough for you and your family?'])]
(second_)
# Out:
#       Occupation Do you think it is enough for you and your family?
# 4    Engineering                                                Yes
# 11   Engineering                                                 No
# 15   Engineering                                                 No
# 18   Engineering                                                 No
# 31   Engineering                                                 No
# 39   Engineering                                                 No
# 47   Engineering                                                 No
# 48   Engineering                                                 No
# 49   Engineering                                                 No
# 50   Engineering                                                 No
# 51   Engineering                                                 No
# 57   Engineering                                                 No
# 64   Engineering                                                 No
# ...

# %% [markdown]
# 69% of Engineers thinks their earnings arent enough while the rest think it is enough for their families.

# %%
health_ =  dam[(dam['Occupation']== 'Health') & (dam['Do you think it is enough for you and your family?'])]
health_
# Out:
#     Occupation Do you think it is enough for you and your family?
# 30      Health                                                 No
# 42      Health                                                 No
# 63      Health                                                 No
# 86      Health                                                 No
# 120     Health                                                 No
# 148     Health                                                 No
# 155     Health                                                 No
# 214     Health                                                 No
# 215     Health                                                 No
# 232     Health                                                 No

# %%
sns.countplot('Do you think it is enough for you and your family?', data = health_)

# %% [markdown]
# all the health workers in the dataset thinks their earnings are not enough for their families

# %%
dev__ =dam[(dam['Occupation']== 'Software Engineering /Computer Design') & (dam['Do you think it is enough for you and your family?'])]  
(dev__)
# Out:
#                                 Occupation  \
# 6    Software Engineering /Computer Design
# 23   Software Engineering /Computer Design
# 46   Software Engineering /Computer Design
# 54   Software Engineering /Computer Design
# 56   Software Engineering /Computer Design
# 66   Software Engineering /Computer Design
# 67   Software Engineering /Computer Design
# 68   Software Engineering /Computer Design
# 79   Software Engineering /Computer Design
# 82   Software Engineering /Computer Design
# 85   Software Engineering /Computer Design
# 88   Software Engineering /Computer Design
# 89   Software Engineering /Computer Design
# 91   Software Engineering /Computer Design
# 96   Software Engineering /Computer Design
# 103  Software Engineering /Computer Design
# 110  Software Engineering /Computer Design
# 111  Software Engineering /Computer Design
# 114  Software Engineering /Computer Design
# 117  Software Engineering /Computer Design
# 118  Software Engineering /Computer Design
# ...

# %%
sns.countplot('Do you think it is enough for you and your family?',data = dev__)

# %% [markdown]
# out of the 50 software engineers in the dataset, only 4 of them thinks their earning is enough for their family

# %%
tx_check =  data.filter(['Occupation', 'Do you pay your tax?' ])
tx_check.head()
# Out:
#            Occupation Do you pay your tax?
# 0                 NaN                   No
# 1              No Job                   No
# 2  Financial Services                  Yes
# 3            Business                  Yes
# 4         Engineering                  Yes

# %%
dev_tx = tx_check[(tx_check['Occupation']== 'Software Engineering /Computer Design') & (tx_check['Do you pay your tax?'])]
len(dev_tx)
# Out:
# 50

# %%
sns.countplot('Do you pay your tax?', data = dev_tx)

# %% [markdown]
# 72% of software engineers from the dataset pay their tax while the rest do not.

# %%
entre_tax = tx_check[(tx_check['Occupation']== 'Entrepreneur') & (tx_check['Do you pay your tax?'])]
len(entre_tax)
# Out:
# 28

# %%
sns.countplot('Do you pay your tax?', data= entre_tax)

# %%
con_tax = tx_check[(tx_check['Occupation']== 'Consultant') & (tx_check['Do you pay your tax?'])]
(con_tax)
# Out:
#      Occupation Do you pay your tax?
# 5    Consultant                  Yes
# 16   Consultant                  Yes
# 38   Consultant                  Yes
# 40   Consultant                  Yes
# 121  Consultant                  Yes
# 150  Consultant                  Yes
# 158  Consultant                  Yes
# 163  Consultant                  Yes
# 170  Consultant                   No
# 186  Consultant                  Yes
# 195  Consultant                  Yes
# 201  Consultant                   No
# 252  Consultant                  Yes
# 262  Consultant                   No
# 275  Consultant                  Yes
# 285  Consultant                  Yes

# %%
sns.countplot('Do you pay your tax?', data = con_tax)

# %% [markdown]
# 81% of Consultants in the dataset pay their tax while the rest do not pay their tax

# %%
bus_tax = tx_check[(tx_check['Occupation']== 'Business') & (tx_check['Do you pay your tax?'])]
(bus_tax).head()
# Out:
#     Occupation Do you pay your tax?
# 3     Business                  Yes
# 43    Business                   No
# 81    Business                  Yes
# 97    Business                  Yes
# 116   Business                  Yes

# %%
sns.countplot('Do you pay your tax?', data = bus_tax)

# %% [markdown]
# 69% of business owner in the respondent pay their rest while 31% of them do not.

# %%
final = data.filter(['Occupation',  'Do you think Nigeria can get better?', 'Are you Happy with your job?'])
final.head()
# Out:
#            Occupation Do you think Nigeria can get better?  \
# 0                 NaN                                  Yes
# 1              No Job                                  Yes
# 2  Financial Services                                  Yes
# 3            Business                                  Yes
# 4         Engineering                                  Yes
#
#   Are you Happy with your job?
# 0                           No
# 1                           No
# 2                          Yes
# 3                          Yes
# 4                          Yes

# %%
bus_sat = final[(final['Occupation']== 'Business') & (final['Do you think Nigeria can get better?']) & (final['Are you Happy with your job?'])]
bus_sat
# Out:
#     Occupation Do you think Nigeria can get better?  \
# 3     Business                                  Yes
# 43    Business                                  Yes
# 81    Business                                  Yes
# 97    Business                                  Yes
# 116   Business                                   No
# 135   Business                                  Yes
# 137   Business                                  Yes
# 179   Business                                   No
# 180   Business                                  Yes
# 200   Business                                  Yes
# 217   Business                                   No
# 224   Business                                  Yes
# 246   Business                                  Yes
# 258   Business                                  Yes
# 259   Business                                  Yes
# 269   Business                                  Yes
#
#     Are you Happy with your job?
# 3                            Yes
# ...

# %%
sns.countplot('Do you think Nigeria can get better?', data = bus_sat)

# %%
sns.countplot('Are you Happy with your job?', data = bus_sat)

# %% [markdown]
# 9/16 of the BUsiness owners in the dataset replied to be satisfied with their jobs and also think NIgeria can be better

# %%
sof_sat = final[(final['Occupation']== 'Software Engineering /Computer Design') & (final['Do you think Nigeria can get better?']) & (final['Are you Happy with your job?'])]
sof_sat
# Out:
#                                 Occupation  \
# 6    Software Engineering /Computer Design
# 23   Software Engineering /Computer Design
# 46   Software Engineering /Computer Design
# 54   Software Engineering /Computer Design
# 56   Software Engineering /Computer Design
# 66   Software Engineering /Computer Design
# 67   Software Engineering /Computer Design
# 68   Software Engineering /Computer Design
# 79   Software Engineering /Computer Design
# 82   Software Engineering /Computer Design
# 85   Software Engineering /Computer Design
# 88   Software Engineering /Computer Design
# 89   Software Engineering /Computer Design
# 91   Software Engineering /Computer Design
# 96   Software Engineering /Computer Design
# 103  Software Engineering /Computer Design
# 110  Software Engineering /Computer Design
# 111  Software Engineering /Computer Design
# 114  Software Engineering /Computer Design
# 117  Software Engineering /Computer Design
# 118  Software Engineering /Computer Design
# ...

# %%
sns.countplot('Do you think Nigeria can get better?', data = sof_sat)

# %%
sns.countplot('Are you Happy with your job?', data = sof_sat)

# %%
Entre_sat=  final[(final['Occupation']== 'Entrepreneur') & (final['Do you think Nigeria can get better?']) & (final['Are you Happy with your job?'])]
Entre_sat
# Out:
#        Occupation Do you think Nigeria can get better?  \
# 8    Entrepreneur                                  Yes
# 9    Entrepreneur                                   No
# 17   Entrepreneur                                  Yes
# 22   Entrepreneur                                   No
# 35   Entrepreneur                                  Yes
# 36   Entrepreneur                                  Yes
# 45   Entrepreneur                                   No
# 53   Entrepreneur                                  Yes
# 58   Entrepreneur                                  Yes
# 62   Entrepreneur                                  Yes
# 65   Entrepreneur                                  Yes
# 72   Entrepreneur                                  Yes
# 74   Entrepreneur                                  Yes
# 76   Entrepreneur                                   No
# 102  Entrepreneur                                  Yes
# 173  Entrepreneur                                  Yes
# ...

# %%
sns.countplot('Do you think Nigeria can get better?', data = Entre_sat)

# %%
sns.countplot('Are you Happy with your job?', data = Entre_sat)

# %%
fin_sat = final[(final['Occupation']== 'Financial Services') & (final['Do you think Nigeria can get better?']) & (final['Are you Happy with your job?'])]
fin_sat
# Out:
#              Occupation Do you think Nigeria can get better?  \
# 2    Financial Services                                  Yes
# 14   Financial Services                                  Yes
# 19   Financial Services                                  Yes
# 20   Financial Services                                  Yes
# 21   Financial Services                                  Yes
# 59   Financial Services                                  Yes
# 60   Financial Services                                  Yes
# 61   Financial Services                                   No
# 75   Financial Services                                  Yes
# 77   Financial Services                                  Yes
# 87   Financial Services                                  Yes
# 101  Financial Services                                  Yes
# 105  Financial Services                                  Yes
# 122  Financial Services                                  Yes
# ...

# %%
stu_sat= final[(final['Occupation']== 'Student') & (final['Do you think Nigeria can get better?']== 'Yes') & (final['Are you Happy with your job?'])]
(stu_sat)
# Out:
#     Occupation Do you think Nigeria can get better?  \
# 7      Student                                  Yes
# 13     Student                                  Yes
# 26     Student                                  Yes
# 27     Student                                  Yes
# 32     Student                                  Yes
# 33     Student                                  Yes
# 52     Student                                  Yes
# 84     Student                                  Yes
# 93     Student                                  Yes
# 94     Student                                  Yes
# 95     Student                                  Yes
# 109    Student                                  Yes
# 126    Student                                  Yes
# 127    Student                                  Yes
# 143    Student                                  Yes
# 147    Student                                  Yes
# 149    Student                                  Yes
# ...

# %%
far_sat=  final[(final['Occupation']== 'Farmer') & (final['Do you think Nigeria can get better?']== 'Yes') & (final['Are you Happy with your job?'])]
far_sat
# Out:
#     Occupation Do you think Nigeria can get better?  \
# 162     Farmer                                  Yes
#
#     Are you Happy with your job?
# 162                           No

# %%
sec= data.filter(['Occupation' , 'What are your other sources of income? '] )
sec.head()
# Out:
#            Occupation What are your other sources of income?
# 0                 NaN                                     NaN
# 1              No Job                            Free Lancing
# 2  Financial Services                            Free Lancing
# 3            Business                      Buying and Selling
# 4         Engineering                              Formal Job

# %%
sec_job = sec[(sec['Occupation']== 'No Job') & (sec['What are your other sources of income? '])]
sec_job
# Out:
#     Occupation       What are your other sources of income?
# 1       No Job                                  Free Lancing
# 12      No Job                                  Free Lancing
# 37      No Job                                  Free Lancing
# 41      No Job                            Buying and Selling
# 44      No Job                            Buying and Selling
# 55      No Job                                    Formal Job
# 69      No Job                                  Free Lancing
# 70      No Job                                  Free Lancing
# 73      No Job                                  Free Lancing
# 100     No Job                                  Free Lancing
# 112     No Job                                          None
# 125     No Job                                          None
# 131     No Job                           Betting (Bet Naija)
# 138     No Job                                  Free Lancing
# ...

# %%
sec_stu = sec[(sec['Occupation']== 'Student') & sec['What are your other sources of income? ']]
sec_stu
# Out:
#     Occupation            What are your other sources of income?
# 7      Student                                 Buying and Selling
# 13     Student                                       Free Lancing
# 24     Student                                       Free Lancing
# 25     Student                                 Buying and Selling
# 26     Student                                       Free Lancing
# 27     Student                                       Free Lancing
# 28     Student                                       Free Lancing
# 29     Student                                Betting (Bet Naija)
# 32     Student                                         Formal Job
# 33     Student                  Free Lancing, Betting (Bet Naija)
# 34     Student                                       Free Lancing
# 52     Student                                 Buying and Selling
# 83     Student                                         Contractor
# ...

# %%
entr_sec = sec[(sec['Occupation']== 'Entrepreneur') & (sec['What are your other sources of income? '])]
entr_sec
# Out:
#        Occupation       What are your other sources of income?
# 8    Entrepreneur                                  Free Lancing
# 9    Entrepreneur                                    Formal Job
# 17   Entrepreneur                                  Free Lancing
# 22   Entrepreneur                                  Free Lancing
# 35   Entrepreneur              Free Lancing, Buying and Selling
# 36   Entrepreneur                                  Free Lancing
# 45   Entrepreneur                                    Contractor
# 53   Entrepreneur                      Free Lancing, Formal Job
# 58   Entrepreneur  Free Lancing, Formal Job, Buying and Selling
# 62   Entrepreneur              Free Lancing, Buying and Selling
# 65   Entrepreneur                      Free Lancing, Formal Job
# 72   Entrepreneur                      Free Lancing, Contractor
# 74   Entrepreneur              Free Lancing, Buying and Selling
# 76   Entrepreneur                                    Formal Job
# ...

# %%
sof_sec = sec[(sec['Occupation'] == 'Software Engineering /Computer Design') & (sec['What are your other sources of income? '])]
sof_sec
# Out:
#                                 Occupation  \
# 6    Software Engineering /Computer Design
# 23   Software Engineering /Computer Design
# 46   Software Engineering /Computer Design
# 54   Software Engineering /Computer Design
# 56   Software Engineering /Computer Design
# 66   Software Engineering /Computer Design
# 67   Software Engineering /Computer Design
# 68   Software Engineering /Computer Design
# 79   Software Engineering /Computer Design
# 82   Software Engineering /Computer Design
# 85   Software Engineering /Computer Design
# 88   Software Engineering /Computer Design
# 89   Software Engineering /Computer Design
# 91   Software Engineering /Computer Design
# 96   Software Engineering /Computer Design
# 103  Software Engineering /Computer Design
# 110  Software Engineering /Computer Design
# 111  Software Engineering /Computer Design
# 114  Software Engineering /Computer Design
# 117  Software Engineering /Computer Design
# 118  Software Engineering /Computer Design
# ...

# %%
eng_sec = sec[(sec['Occupation']== 'Engineering') & (sec['What are your other sources of income? '])]
eng_sec
# Out:
#       Occupation  What are your other sources of income?
# 4    Engineering                               Formal Job
# 11   Engineering                               Contractor
# 15   Engineering                               Formal Job
# 18   Engineering                             Free Lancing
# 31   Engineering  Betting (Bet Naija), Buying and Selling
# 39   Engineering                      Betting (Bet Naija)
# 47   Engineering                               Formal Job
# 48   Engineering        Free Lancing, Betting (Bet Naija)
# 49   Engineering                             Free Lancing
# 50   Engineering                             Free Lancing
# 51   Engineering                       Buying and Selling
# 57   Engineering                             Free Lancing
# 64   Engineering                             Free Lancing
# 78   Engineering                             Free Lancing
# 80   Engineering                             Free Lancing
# ...

# %%
hlth_sec = sec[(sec['Occupation'] == 'Health') & (sec['What are your other sources of income? '])]
hlth_sec
# Out:
#     Occupation What are your other sources of income?
# 30      Health                              Contractor
# 42      Health        Free Lancing, Buying and Selling
# 63      Health                            Free Lancing
# 86      Health                                    None
# 120     Health                                    None
# 148     Health                                    None
# 155     Health                                    None
# 214     Health        Free Lancing, Buying and Selling
# 215     Health                            Free Lancing
# 232     Health                                    None

# %% [markdown]
# from the cells above, we can see that Free lancing, bying and selling cuts across all the professions! that is most professional take second jobs or side hustles in free lancing, selling and buying.

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(211)
ax1.plot()
